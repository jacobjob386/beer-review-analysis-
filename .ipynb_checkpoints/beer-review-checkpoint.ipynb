# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
beer_info = pd.read_csv("beer_info.csv")
beer_reviews = pd.read_csv("beer_reviews.csv")
review_details = pd.read_csv("review_details.csv")

# %%
beer_info.shape
# Out:
# (242921, 4)

# %%
beer_reviews.shape
# Out:
# (1654502, 4)

# %%
review_details.shape
# Out:
# (1654502, 5)

# %%
beer_info.describe()
# Out:
#             beer_abv
# count  204526.000000
# mean        6.558847
# std         2.197321
# min         0.010000
# 25%         5.000000
# 50%         6.000000
# 75%         7.800000
# max        57.700000

# %%
beer_info.isna().sum()
# Out:
# beer_name           0
# brewery_name       12
# beer_style          0
# beer_abv        38395
# dtype: int64

# %%
merged = pd.merge(beer_reviews, beer_info, on = "beer_name", how = "left")

# %%
merged.isna().sum()
# Out:
# review_id                  0
# beer_name                  0
# reviewer_username        425
# overall_score          98326
# brewery_name          966336
# beer_style            966334
# beer_abv             1000301
# dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(y = merged["beer_abv"])
# Out:
# <Axes: ylabel='beer_abv'>

# %%
import pandas as pd

col = merged["beer_abv"]

Q1 = col.quantile(0.25)
Q3 = col.quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = merged[(col < lower) | (col > upper)]

print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 12391

# %%
merged.head()
# Out:
#    review_id                beer_name reviewer_username  overall_score  \
# 0          1            Sausa Weizen            stcules            1.5
# 1          2                Red Moon            stcules            3.0
# 2          3  BLACK HORSE BLACK BEER            stcules            3.0
# 3          4              sausa pils            stcules            3.0
# 4          5           Cauldron Dipa     johnmichaelsen            4.0
#
#       brewery_name           beer_style  beer_abv
# 0              NaN                  NaN       NaN
# 1  VECCHIO BIRRAIO   English Strong Ale       6.2
# 2              NaN                  NaN       NaN
# 3  VECCHIO BIRRAIO     german pilsener        5.0
# 4              NaN                  NaN       NaN

# %%
merged2= pd.merge(merged, review_details, on="review_id", how="left")

# %%
merged2.head()
# Out:
#    review_id                beer_name reviewer_username  overall_score  \
# 0          1            Sausa Weizen            stcules            1.5
# 1          2                Red Moon            stcules            3.0
# 2          3  BLACK HORSE BLACK BEER            stcules            3.0
# 3          4              sausa pils            stcules            3.0
# 4          5           Cauldron Dipa     johnmichaelsen            4.0
#
#       brewery_name           beer_style  beer_abv  aroma_score  \
# 0              NaN                  NaN       NaN          2.0
# 1  VECCHIO BIRRAIO   English Strong Ale       6.2          2.5
# 2              NaN                  NaN       NaN          2.5
# 3  VECCHIO BIRRAIO     german pilsener        5.0          3.0
# 4              NaN                  NaN       NaN          4.5
#
#    appearance_score  taste_score  palate_score
# 0               2.5          1.5           1.5
# 1               3.0          3.0           3.0
# 2               3.0          3.0           3.0
# 3               3.5          3.0           2.5
# 4               4.0          4.5           4.0

# %%
merged2.isna().sum()
# Out:
# review_id                  0
# beer_name                  0
# reviewer_username        425
# overall_score          98326
# brewery_name          966336
# beer_style            966334
# beer_abv             1000301
# aroma_score           145465
# appearance_score           0
# taste_score           135476
# palate_score          231982
# dtype: int64

# %%
df = merged2

# %%
df["brewery_name"] = df["brewery_name"].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# review_id                  0
# beer_name                  0
# reviewer_username        425
# overall_score          98326
# brewery_name               0
# beer_style            966334
# beer_abv             1000301
# aroma_score           145465
# appearance_score           0
# taste_score           135476
# palate_score          231982
# dtype: int64

# %%
df["beer_style"] = df["beer_style"].fillna(df["beer_style"].mode()[0])

# %%
df["beer_abv"].hist()
# Out:
# <Axes: >

# %%
df["beer_abv"] = df["beer_abv"].fillna(df["beer_abv"].median)

# %%
df["aroma_score"].hist()
# Out:
# <Axes: >

# %%
df["aroma_score"] = df["aroma_score"].fillna(df["aroma_score"].median)

# %%
df["aroma_score"] = pd.to_numeric(df["aroma_score"], errors="coerce")

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer()

cols = ["overall_score", "aroma_score", "taste_score", "palate_score", "appearance_score"]

df[cols] = imputer.fit_transform(df[cols])
# Out:
# C:\Users\jacob\AppData\Roaming\Python\Python313\site-packages\sklearn\impute\_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
df = df.dropna(subset=["reviewer_username"])

# %%
df.isna().sum()
# Out:
# review_id            0
# beer_name            0
# reviewer_username    0
# overall_score        0
# brewery_name         0
# beer_style           0
# beer_abv             0
# aroma_score          0
# appearance_score     0
# taste_score          0
# palate_score         0
# dtype: int64

# %%
df.to_csv("beer.csv", index=False)

# %%
pwd
# Out:
# 'C:\\Users\\jacob'
